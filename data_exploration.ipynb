# %% [markdown]
# Principal Component Analysis (PCA)

# %%
# Loading libraries
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Loading csv data (combined.csv) into dataframe
df = pd.read_csv('data/combined.csv')

# Removing unnecessary column that holds index
df = df.drop(labels=['Unnamed: 0'],axis=1)
attributes = df.columns.tolist()

# %%
# Describing the dataframe
print(df.head(10))
print(df.shape)
print(attributes)
# Out:
#    distance cab_type     time_stamp              destination  \
# 0      0.44     Lyft  1544952607890            North Station
# 1      0.44     Lyft  1543284023677            North Station
# 2      0.44     Lyft  1543284023677            North Station
# 3      0.44     Lyft  1543366822198            North Station
# 4      0.44     Lyft  1543553582749            North Station
# 5      0.44     Lyft  1543463360223            North Station
# 6      0.44     Lyft  1543463360223            North Station
# 7      0.44     Lyft  1543463360223            North Station
# 8      0.44     Lyft  1545071112138            North Station
# 9      1.08     Lyft  1543208580200  Northeastern University
#
#              source  price  surge_multiplier  \
# 0  Haymarket Square    5.0               1.0
# 1  Haymarket Square   11.0               1.0
# 2  Haymarket Square   11.0               1.0
# 3  Haymarket Square    7.0               1.0
# 4  Haymarket Square   26.0               1.0
# ...

# %%
# Finding correlation matrix
df.corr()

# Visualizing correlation matrix
cm = df.corr()
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.set_theme(style="white")
plt.figure(figsize=(15,15))
sns.set_theme(style="white")
sns.heatmap(cm,vmax=1,square=True,annot=True,cmap=cmap)
plt.title('Correlation between different ride attributes')
# Out:
# Text(0.5, 1.0, 'Correlation between different ride attributes')

# %%
new_df = df[['price', 'temp', 'clouds', 'pressure', 'rain', 'humidity', 'wind']]
sns.pairplot(new_df)
